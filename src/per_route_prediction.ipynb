# %%
import bus_prediction
import os
import pandas as pd
from constants import DATA_DIR

def load_bus_data():
    path = os.path.join(DATA_DIR, "dataset_routes.csv")
    df = pd.read_csv(path)
    return df

bus_data = load_bus_data()
bus_data["time_bucket"] = pd.to_datetime(bus_data["time_bucket"], utc=True)
X_train, y_train, X_test, y_test = bus_prediction.prepare_bus_data(bus_data)
# Out:
# /Users/legendword/python3/lib/python3.12/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /var/folders/q2/2tqxwv350tlgcm99pc70ct3w0000gn/T/ipykernel_38534/4238995566.py:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
print(X_train[0:5])
# Out:
#   vehicle.trip.route_id  vehicle.trip.direction_id               time_bucket  \
# 0                     1                        0.0 2023-11-20 12:20:00+00:00
# 1                     1                        0.0 2023-11-20 12:40:00+00:00
# 2                     1                        0.0 2023-11-20 13:00:00+00:00
# 3                     1                        0.0 2023-11-20 13:20:00+00:00
# 4                     1                        0.0 2023-11-20 13:40:00+00:00
#
#    holiday  weekday  temp  dwpt  rhum  prcp   wdir  wspd    pres  coco  \
# 0        0        0  15.0   3.5  46.0   0.0   20.0  27.7  1023.5   1.0
# 1        0        0  15.0   3.5  46.0   0.0   20.0  27.7  1023.5   1.0
# 2        0        0  12.2   4.4  59.0   0.0  140.0   9.4  1023.2   1.0
# 3        0        0  12.2   4.4  59.0   0.0  140.0   9.4  1023.2   1.0
# 4        0        0  12.2   4.4  59.0   0.0  140.0   9.4  1023.2   1.0
#
#    avg_delay  month  day  hour  minute
# 0        0.0     11   20    12      20
# 1        1.0     11   20    12      40
# 2        0.2     11   20    13       0
# 3        1.0     11   20    13      20
# 4        2.6     11   20    13      40

# %%
route_ids = bus_data['vehicle.trip.route_id'].unique()
print(route_ids)
# Out:
# [1 12 14 '14' '14R' '15' '18' 18 19 '19' '1X' '2' 2 21 22 23 24 25 27 28
#  '28' '28R' '29' 29 30 '30' '30X' '31' 31 33 35 36 37 38 '38' '38R' '39'
#  39 43 44 45 48 49 5 52 54 55 56 57 58 '58' '5R' '6' 6 66 67 7 714 8 '8'
#  '8AX' '8BX' '9' 9 90 91 '91' '9R' 'CA' 'F' 'FBUS' 'J' 'K' 'KBUS' 'KLM'
#  'L' 'LBUS' 'LOWL' 'M' 'MBUS' 'N' 'NBUS' 'NOWL' 'PH' 'PM' 'S' 'T' 'TBUS']

# %%
route_train_sizes = {}
route_test_mses = {}

for route_id in route_ids:
    route_X_train = X_train[X_train['vehicle.trip.route_id'] == route_id]
    route_y_train = y_train[X_train['vehicle.trip.route_id'] == route_id]
    route_X_test = X_test[X_test['vehicle.trip.route_id'] == route_id]
    route_y_test = y_test[X_test['vehicle.trip.route_id'] == route_id]
    if route_X_train.shape[0] == 0 or route_X_test.shape[0] == 0:
        print(f"Skipping route {route_id} due to empty train/test set.")
        continue
    route_train_sizes[route_id] = route_X_train.shape[0]
    print(f"Route ID: {route_id}")
    print(f"Train set size: {route_X_train.shape}")
    print(f"Test set size: {route_X_test.shape}")
    route_X_train = route_X_train.drop(columns=['vehicle.trip.route_id'])
    route_X_test = route_X_test.drop(columns=['vehicle.trip.route_id'])
    xgboost_predictor = bus_prediction.XGBoostPredictor(lagged_features=["avg_delay"], lag_offsets=[1, 2, 3, 24*3], avg_features=["avg_delay"], avg_ranges=[24*3, 48*3, 72*3])
    xgboost_predictor.train(route_X_train, route_y_train)
    xgboost_mse = xgboost_predictor.evaluate(route_X_test, route_y_test)
    route_test_mses[route_id] = xgboost_mse
    print(f"XGBoost Test MSE: {xgboost_mse:.4f}")


# Compute overall test MSE
overall_test_mse = 0
for route_id in route_ids:
    if route_id in route_test_mses:
        overall_test_mse += route_test_mses[route_id] * route_train_sizes[route_id]
overall_test_mse /= sum(route_train_sizes.values())
print(f"Overall Test MSE: {overall_test_mse:.4f}")
# Out:
# Route ID: 1
# Train set size: (30833, 18)
# Test set size: (3759, 18)
# Validation MSE: 2.9038
# XGBoost Test MSE: 3.4116
# Route ID: 12
# Train set size: (25824, 18)
# Test set size: (3157, 18)
# Validation MSE: 9.5742
# XGBoost Test MSE: 8.5528
# Route ID: 14
# Train set size: (32529, 18)
# Test set size: (2202, 18)
# Validation MSE: 2.6590
# XGBoost Test MSE: 4.0659
# Route ID: 14
# Train set size: (3683, 18)
# Test set size: (2201, 18)
# Validation MSE: 2.8579
# XGBoost Test MSE: 7.3426
# Route ID: 14R
# Train set size: (27188, 18)
# Test set size: (3320, 18)
# Validation MSE: 3.3537
# XGBoost Test MSE: 7.8527
# Route ID: 15
# Train set size: (25663, 18)
# Test set size: (3104, 18)
# Validation MSE: 6.6722
# XGBoost Test MSE: 7.1675
# Skipping route 18 due to empty train/test set.
# Route ID: 18
# Train set size: (24984, 18)
# Test set size: (3090, 18)
# Validation MSE: 3.5045
# XGBoost Test MSE: 4.9588
# Skipping route 19 due to empty train/test set.
# Route ID: 19
# Train set size: (22600, 18)
# Test set size: (3336, 18)
# Validation MSE: 18.1465
# XGBoost Test MSE: 9.0374
# Route ID: 1X
# Train set size: (2184, 18)
# Test set size: (238, 18)
# Validation MSE: 4.2801
# XGBoost Test MSE: 10.3053
# Skipping route 2 due to empty train/test set.
# Route ID: 2
# Train set size: (15530, 18)
# Test set size: (2408, 18)
# Validation MSE: 2.9490
# XGBoost Test MSE: 10.4996
# Route ID: 21
# Train set size: (26546, 18)
# Test set size: (3212, 18)
# Validation MSE: 1.9331
# XGBoost Test MSE: 3.8184
# Route ID: 22
# Train set size: (36161, 18)
# Test set size: (4402, 18)
# Validation MSE: 3.8176
# XGBoost Test MSE: 4.9586
# Route ID: 23
# Train set size: (25682, 18)
# Test set size: (3134, 18)
# Validation MSE: 5.2996
# XGBoost Test MSE: 7.2559
# Route ID: 24
# Train set size: (36179, 18)
# Test set size: (4404, 18)
# Validation MSE: 5.7875
# XGBoost Test MSE: 2.5882
# Route ID: 25
# Train set size: (29149, 18)
# Test set size: (3697, 18)
# Validation MSE: 11.6342
# XGBoost Test MSE: 9.6832
# Route ID: 27
# Train set size: (27188, 18)
# Test set size: (3325, 18)
# Validation MSE: 11.8676
# XGBoost Test MSE: 12.7910
# Skipping route 28 due to empty train/test set.
# Route ID: 28
# Train set size: (21724, 18)
# Test set size: (3690, 18)
# Validation MSE: 8.8935
# XGBoost Test MSE: 5.6172
# Route ID: 28R
# Train set size: (13331, 18)
# Test set size: (1586, 18)
# Validation MSE: 2.0182
# XGBoost Test MSE: 4.7515
# Route ID: 29
# Train set size: (23339, 18)
# Test set size: (1866, 18)
# Validation MSE: 3.9973
# XGBoost Test MSE: 18.0495
# Route ID: 29
# Train set size: (7173, 18)
# Test set size: (1871, 18)
# Validation MSE: 3.2990
# XGBoost Test MSE: 6.0381
# Route ID: 30
# Train set size: (21915, 18)
# Test set size: (1809, 18)
# Validation MSE: 6.5623
# XGBoost Test MSE: 3.9919
# Route ID: 30
# Train set size: (8155, 18)
# Test set size: (1790, 18)
# Validation MSE: 3.3536
# XGBoost Test MSE: 4.4709
# Skipping route 30X due to empty train/test set.
# Route ID: 31
# Train set size: (21017, 18)
# Test set size: (1719, 18)
# Validation MSE: 4.6866
# XGBoost Test MSE: 3.6897
# Route ID: 31
# Train set size: (7033, 18)
# Test set size: (1706, 18)
# Validation MSE: 4.7814
# XGBoost Test MSE: 5.1130
# Route ID: 33
# Train set size: (26923, 18)
# Test set size: (3287, 18)
# Validation MSE: 4.0566
# XGBoost Test MSE: 4.5244
# Route ID: 35
# Train set size: (21412, 18)
# Test set size: (2587, 18)
# Validation MSE: 5.6380
# XGBoost Test MSE: 3.3500
# Route ID: 36
# Train set size: (24476, 18)
# Test set size: (2940, 18)
# Validation MSE: 10.1021
# XGBoost Test MSE: 20.2388
# Route ID: 37
# Train set size: (23515, 18)
# Test set size: (2885, 18)
# Validation MSE: 5.2887
# XGBoost Test MSE: 7.7273
# Skipping route 38 due to empty train/test set.
# Route ID: 38
# Train set size: (21842, 18)
# Test set size: (4393, 18)
# Validation MSE: 3.4436
# XGBoost Test MSE: 4.8650
# Route ID: 38R
# Train set size: (26211, 18)
# Test set size: (3191, 18)
# Validation MSE: 7.8136
# XGBoost Test MSE: 3.6089
# Route ID: 39
# Train set size: (8966, 18)
# Test set size: (933, 18)
# Validation MSE: 16.8996
# XGBoost Test MSE: 321.5621
# Route ID: 39
# Train set size: (6503, 18)
# Test set size: (925, 18)
# Validation MSE: 15.3238
# XGBoost Test MSE: 288.8389
# Route ID: 43
# Train set size: (30431, 18)
# Test set size: (3708, 18)
# Validation MSE: 6.8300
# XGBoost Test MSE: 2.7625
# Route ID: 44
# Train set size: (36092, 18)
# Test set size: (4395, 18)
# Validation MSE: 3.0675
# XGBoost Test MSE: 4.0713
# Route ID: 45
# Train set size: (27807, 18)
# Test set size: (3357, 18)
# Validation MSE: 2.6515
# XGBoost Test MSE: 3.3033
# Route ID: 48
# Train set size: (36049, 18)
# Test set size: (4386, 18)
# Validation MSE: 3.8902
# XGBoost Test MSE: 4.5977
# Route ID: 49
# Train set size: (31004, 18)
# Test set size: (3777, 18)
# Validation MSE: 2.2670
# XGBoost Test MSE: 2.1260
# Route ID: 5
# Train set size: (36166, 18)
# Test set size: (4403, 18)
# Validation MSE: 3.4833
# XGBoost Test MSE: 3.4692
# Route ID: 52
# Train set size: (24136, 18)
# Test set size: (2949, 18)
# Validation MSE: 4.9587
# XGBoost Test MSE: 5.8742
# Route ID: 54
# Train set size: (26369, 18)
# Test set size: (3218, 18)
# Validation MSE: 8.6939
# XGBoost Test MSE: 10.0916
# Route ID: 55
# Train set size: (26604, 18)
# Test set size: (3211, 18)
# Validation MSE: 4.3170
# XGBoost Test MSE: 26.7767
# Route ID: 56
# Train set size: (21319, 18)
# Test set size: (2619, 18)
# Validation MSE: 9.1278
# XGBoost Test MSE: 28.6011
# Route ID: 57
# Train set size: (26670, 18)
# Test set size: (3238, 18)
# Validation MSE: 6.4005
# XGBoost Test MSE: 9.4866
# Route ID: 58
# Train set size: (22273, 18)
# Test set size: (1607, 18)
# Validation MSE: 6.0037
# XGBoost Test MSE: 5.1575
# Route ID: 58
# Train set size: (3974, 18)
# Test set size: (1590, 18)
# Validation MSE: 6.5709
# XGBoost Test MSE: 9.6760
# Route ID: 5R
# Train set size: (13528, 18)
# Test set size: (1597, 18)
# Validation MSE: 3.1699
# XGBoost Test MSE: 4.0387
# Skipping route 6 due to empty train/test set.
# Route ID: 6
# Train set size: (18392, 18)
# Test set size: (3732, 18)
# Validation MSE: 6.5864
# XGBoost Test MSE: 3.1965
# Route ID: 66
# Train set size: (23791, 18)
# Test set size: (2894, 18)
# Validation MSE: 4.5958
# XGBoost Test MSE: 3.0706
# Route ID: 67
# Train set size: (24282, 18)
# Test set size: (2944, 18)
# Validation MSE: 14.7999
# XGBoost Test MSE: 62.8771
# Route ID: 7
# Train set size: (27506, 18)
# Test set size: (3342, 18)
# Validation MSE: 2.0651
# XGBoost Test MSE: 2.8072
# Route ID: 714
# Train set size: (1025, 18)
# Test set size: (126, 18)
# Validation MSE: 38.6568
# XGBoost Test MSE: 218.5123
# Route ID: 8
# Train set size: (21290, 18)
# Test set size: (1748, 18)
# Validation MSE: 8.2083
# XGBoost Test MSE: 3.7076
# Route ID: 8
# Train set size: (7414, 18)
# Test set size: (1783, 18)
# Validation MSE: 19.2951
# XGBoost Test MSE: 13.1936
# Route ID: 8AX
# Train set size: (4252, 18)
# Test set size: (519, 18)
# Validation MSE: 26.5084
# XGBoost Test MSE: 14.6160
# Route ID: 8BX
# Train set size: (4377, 18)
# Test set size: (517, 18)
# Validation MSE: 26.4871
# XGBoost Test MSE: 76.9046
# Skipping route 9 due to empty train/test set.
# Route ID: 9
# Train set size: (16137, 18)
# Test set size: (3669, 18)
# Validation MSE: 5.7585
# XGBoost Test MSE: 9.4914
# Route ID: 90
# Train set size: (8321, 18)
# Test set size: (1025, 18)
# Validation MSE: 12.1314
# XGBoost Test MSE: 11.8764
# Skipping route 91 due to empty train/test set.
# Route ID: 91
# Train set size: (7018, 18)
# Test set size: (1345, 18)
# Validation MSE: 7.5281
# XGBoost Test MSE: 9.2103
# Route ID: 9R
# Train set size: (13277, 18)
# Test set size: (1571, 18)
# Validation MSE: 9.7836
# XGBoost Test MSE: 10.3096
# Route ID: CA
# Train set size: (12589, 18)
# Test set size: (2043, 18)
# Validation MSE: 150.7826
# XGBoost Test MSE: 375.3279
# Route ID: F
# Train set size: (24721, 18)
# Test set size: (3008, 18)
# Validation MSE: 17.9019
# XGBoost Test MSE: 14.8067
# Skipping route FBUS due to empty train/test set.
# Route ID: J
# Train set size: (30156, 18)
# Test set size: (3725, 18)
# Validation MSE: 11.7111
# XGBoost Test MSE: 8.0938
# Route ID: K
# Train set size: (27085, 18)
# Test set size: (3288, 18)
# Validation MSE: 9.6234
# XGBoost Test MSE: 13.0678
# Route ID: KBUS
# Train set size: (4581, 18)
# Test set size: (543, 18)
# Validation MSE: 40.8949
# XGBoost Test MSE: 14.7603
# Skipping route KLM due to empty train/test set.
# Skipping route L due to empty train/test set.
# Skipping route LBUS due to empty train/test set.
# Route ID: LOWL
# Train set size: (13252, 18)
# Test set size: (1302, 18)
# Validation MSE: 6.2537
# XGBoost Test MSE: 7.8569
# Route ID: M
# Train set size: (28579, 18)
# Test set size: (3632, 18)
# Validation MSE: 19.2122
# XGBoost Test MSE: 17.1965
# Skipping route MBUS due to empty train/test set.
# Route ID: N
# Train set size: (29243, 18)
# Test set size: (3559, 18)
# Validation MSE: 20.1735
# XGBoost Test MSE: 3.4336
# Route ID: NBUS
# Train set size: (4094, 18)
# Test set size: (476, 18)
# Validation MSE: 20.3753
# XGBoost Test MSE: 11.5055
# Route ID: NOWL
# Train set size: (9569, 18)
# Test set size: (1161, 18)
# Validation MSE: 12.4530
# XGBoost Test MSE: 10.2960
# Route ID: PH
# Train set size: (16974, 18)
# Test set size: (2639, 18)
# Validation MSE: 161.8404
# XGBoost Test MSE: 206.9841
# Route ID: PM
# Train set size: (15429, 18)
# Test set size: (2423, 18)
# Validation MSE: 179.6142
# XGBoost Test MSE: 281.6541
# Skipping route S due to empty train/test set.
# Route ID: T
# Train set size: (29400, 18)
# Test set size: (3525, 18)
# Validation MSE: 9.2295
# XGBoost Test MSE: 11.3609
# Route ID: TBUS
# Train set size: (3862, 18)
# Test set size: (472, 18)
# Validation MSE: 22.1421
# XGBoost Test MSE: 83.0905
# Overall Test MSE: 20.6757

# %% [markdown]
# ### Day-ahead

# %%
route_train_sizes = {}
route_test_mses = {}

for route_id in route_ids:
    route_X_train = X_train[X_train['vehicle.trip.route_id'] == route_id]
    route_y_train = y_train[X_train['vehicle.trip.route_id'] == route_id]
    route_X_test = X_test[X_test['vehicle.trip.route_id'] == route_id]
    route_y_test = y_test[X_test['vehicle.trip.route_id'] == route_id]
    if route_X_train.shape[0] == 0 or route_X_test.shape[0] == 0:
        print(f"Skipping route {route_id} due to empty train/test set.")
        continue
    route_train_sizes[route_id] = route_X_train.shape[0]
    print(f"Route ID: {route_id}")
    print(f"Train set size: {route_X_train.shape}")
    print(f"Test set size: {route_X_test.shape}")
    route_X_train = route_X_train.drop(columns=['vehicle.trip.route_id'])
    route_X_test = route_X_test.drop(columns=['vehicle.trip.route_id'])
    xgboost_predictor = bus_prediction.XGBoostPredictor(lagged_features=["avg_delay"], lag_offsets=[24*3, 24*3+1, 24*3+2, 48*3])
    xgboost_predictor.train(route_X_train, route_y_train)
    try:
      xgboost_mse = xgboost_predictor.evaluate(route_X_test, route_y_test)
    except Exception as e:
      print(f"Error evaluating route {route_id}: {e}")
      continue
    route_test_mses[route_id] = xgboost_mse
    print(f"XGBoost Test MSE: {xgboost_mse:.4f}")


# Compute overall test MSE
overall_test_mse = 0
for route_id in route_ids:
    if route_id in route_test_mses:
        overall_test_mse += route_test_mses[route_id] * route_train_sizes[route_id]
overall_test_mse /= sum(route_train_sizes.values())
print(f"Overall Test MSE: {overall_test_mse:.4f}")
# Out:
# Route ID: 1
# Train set size: (30833, 18)
# Test set size: (3759, 18)
# Validation MSE: 4.1452
# XGBoost Test MSE: 5.2227
# Route ID: 12
# Train set size: (25824, 18)
# Test set size: (3157, 18)
# Validation MSE: 14.6051
# XGBoost Test MSE: 14.2523
# Route ID: 14
# Train set size: (32529, 18)
# Test set size: (2202, 18)
# Validation MSE: 4.3449
# XGBoost Test MSE: 7.9107
# Route ID: 14
# Train set size: (3683, 18)
# Test set size: (2201, 18)
# Validation MSE: 4.5237
# XGBoost Test MSE: 14.6182
# Route ID: 14R
# Train set size: (27188, 18)
# Test set size: (3320, 18)
# Validation MSE: 5.1113
# XGBoost Test MSE: 9.5723
# Route ID: 15
# Train set size: (25663, 18)
# Test set size: (3104, 18)
# Validation MSE: 8.5290
# XGBoost Test MSE: 10.6498
# Skipping route 18 due to empty train/test set.
# Route ID: 18
# Train set size: (24984, 18)
# Test set size: (3090, 18)
# Validation MSE: 4.0343
# XGBoost Test MSE: 5.2116
# Skipping route 19 due to empty train/test set.
# Route ID: 19
# Train set size: (22600, 18)
# Test set size: (3336, 18)
# Validation MSE: 20.6887
# XGBoost Test MSE: 14.5028
# Route ID: 1X
# Train set size: (2184, 18)
# Test set size: (238, 18)
# Validation MSE: 5.8693
# XGBoost Test MSE: 14.5089
# Skipping route 2 due to empty train/test set.
# Route ID: 2
# Train set size: (15530, 18)
# Test set size: (2408, 18)
# Validation MSE: 3.0515
# XGBoost Test MSE: 17.7436
# Route ID: 21
# Train set size: (26546, 18)
# Test set size: (3212, 18)
# Validation MSE: 2.2882
# XGBoost Test MSE: 5.7852
# Route ID: 22
# Train set size: (36161, 18)
# Test set size: (4402, 18)
# Validation MSE: 7.4234
# XGBoost Test MSE: 8.9836
# Route ID: 23
# Train set size: (25682, 18)
# Test set size: (3134, 18)
# Validation MSE: 6.0477
# XGBoost Test MSE: 7.8281
# Route ID: 24
# Train set size: (36179, 18)
# Test set size: (4404, 18)
# Validation MSE: 6.3304
# XGBoost Test MSE: 3.3251
# Route ID: 25
# Train set size: (29149, 18)
# Test set size: (3697, 18)
# Validation MSE: 19.3417
# XGBoost Test MSE: 11.8848
# Route ID: 27
# Train set size: (27188, 18)
# Test set size: (3325, 18)
# Validation MSE: 14.1345
# XGBoost Test MSE: 16.1219
# Skipping route 28 due to empty train/test set.
# Route ID: 28
# Train set size: (21724, 18)
# Test set size: (3690, 18)
# Validation MSE: 14.3068
# XGBoost Test MSE: 9.2125
# Route ID: 28R
# Train set size: (13331, 18)
# Test set size: (1586, 18)
# Validation MSE: 2.4990
# XGBoost Test MSE: 6.4662
# Route ID: 29
# Train set size: (23339, 18)
# Test set size: (1866, 18)
# Validation MSE: 5.2489
# XGBoost Test MSE: 19.4805
# Route ID: 29
# Train set size: (7173, 18)
# Test set size: (1871, 18)
# Validation MSE: 4.0948
# XGBoost Test MSE: 7.4005
# Route ID: 30
# Train set size: (21915, 18)
# Test set size: (1809, 18)
# Validation MSE: 8.5130
# XGBoost Test MSE: 4.2758
# Route ID: 30
# Train set size: (8155, 18)
# Test set size: (1790, 18)
# Validation MSE: 4.4476
# XGBoost Test MSE: 5.4564
# Skipping route 30X due to empty train/test set.
# Route ID: 31
# Train set size: (21017, 18)
# Test set size: (1719, 18)
# Validation MSE: 6.4928
# XGBoost Test MSE: 4.7366
# Route ID: 31
# Train set size: (7033, 18)
# Test set size: (1706, 18)
# Validation MSE: 9.1995
# XGBoost Test MSE: 6.0797
# Route ID: 33
# Train set size: (26923, 18)
# Test set size: (3287, 18)
# Validation MSE: 5.6578
# XGBoost Test MSE: 7.5111
# Route ID: 35
# Train set size: (21412, 18)
# Test set size: (2587, 18)
# Validation MSE: 6.9134
# XGBoost Test MSE: 4.0862
# Route ID: 36
# Train set size: (24476, 18)
# Test set size: (2940, 18)
# Validation MSE: 11.6491
# XGBoost Test MSE: 27.2643
# Route ID: 37
# Train set size: (23515, 18)
# Test set size: (2885, 18)
# Validation MSE: 6.3131
# XGBoost Test MSE: 9.2069
# Skipping route 38 due to empty train/test set.
# Route ID: 38
# Train set size: (21842, 18)
# Test set size: (4393, 18)
# Validation MSE: 6.7620
# XGBoost Test MSE: 7.0399
# Route ID: 38R
# Train set size: (26211, 18)
# Test set size: (3191, 18)
# Validation MSE: 9.9497
# XGBoost Test MSE: 3.7922
# Route ID: 39
# Train set size: (8966, 18)
# Test set size: (933, 18)
# Validation MSE: 14.4507
# XGBoost Test MSE: 308.6571
# Route ID: 39
# Train set size: (6503, 18)
# Test set size: (925, 18)
# Validation MSE: 22.5776
# XGBoost Test MSE: 334.8856
# Route ID: 43
# Train set size: (30431, 18)
# Test set size: (3708, 18)
# Validation MSE: 9.5875
# XGBoost Test MSE: 4.2613
# Route ID: 44
# Train set size: (36092, 18)
# Test set size: (4395, 18)
# Validation MSE: 3.7295
# XGBoost Test MSE: 5.2153
# Route ID: 45
# Train set size: (27807, 18)
# Test set size: (3357, 18)
# Validation MSE: 3.8265
# XGBoost Test MSE: 3.5640
# Route ID: 48
# Train set size: (36049, 18)
# Test set size: (4386, 18)
# Validation MSE: 5.1094
# XGBoost Test MSE: 6.3467
# Route ID: 49
# Train set size: (31004, 18)
# Test set size: (3777, 18)
# Validation MSE: 2.9318
# XGBoost Test MSE: 2.7723
# Route ID: 5
# Train set size: (36166, 18)
# Test set size: (4403, 18)
# Validation MSE: 5.1138
# XGBoost Test MSE: 4.7604
# Route ID: 52
# Train set size: (24136, 18)
# Test set size: (2949, 18)
# Validation MSE: 5.9255
# XGBoost Test MSE: 6.6915
# Route ID: 54
# Train set size: (26369, 18)
# Test set size: (3218, 18)
# Validation MSE: 9.1847
# XGBoost Test MSE: 10.3655
# Route ID: 55
# Train set size: (26604, 18)
# Test set size: (3211, 18)
# Validation MSE: 5.1382
# XGBoost Test MSE: 31.1434
# Route ID: 56
# Train set size: (21319, 18)
# Test set size: (2619, 18)
# Validation MSE: 10.2508
# XGBoost Test MSE: 44.5887
# Route ID: 57
# Train set size: (26670, 18)
# Test set size: (3238, 18)
# Validation MSE: 7.3436
# XGBoost Test MSE: 12.0200
# Route ID: 58
# Train set size: (22273, 18)
# Test set size: (1607, 18)
# Validation MSE: 7.1577
# XGBoost Test MSE: 5.3722
# Route ID: 58
# Train set size: (3974, 18)
# Test set size: (1590, 18)
# Validation MSE: 11.7963
# XGBoost Test MSE: 10.5199
# Route ID: 5R
# Train set size: (13528, 18)
# Test set size: (1597, 18)
# Validation MSE: 4.2830
# XGBoost Test MSE: 5.1990
# Skipping route 6 due to empty train/test set.
# Route ID: 6
# Train set size: (18392, 18)
# Test set size: (3732, 18)
# Validation MSE: 8.0810
# XGBoost Test MSE: 5.6312
# Route ID: 66
# Train set size: (23791, 18)
# Test set size: (2894, 18)
# Validation MSE: 5.9382
# XGBoost Test MSE: 4.0539
# Route ID: 67
# Train set size: (24282, 18)
# Test set size: (2944, 18)
# Validation MSE: 21.0129
# XGBoost Test MSE: 103.6721
# Route ID: 7
# Train set size: (27506, 18)
# Test set size: (3342, 18)
# Validation MSE: 4.0448
# XGBoost Test MSE: 3.6172
# Route ID: 714
# Train set size: (1025, 18)
# Test set size: (126, 18)
# Validation MSE: 22.3964
# Error evaluating route 714: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
# Route ID: 8
# Train set size: (21290, 18)
# Test set size: (1748, 18)
# Validation MSE: 13.1033
# XGBoost Test MSE: 5.7369
# Route ID: 8
# Train set size: (7414, 18)
# Test set size: (1783, 18)
# Validation MSE: 12.0967
# XGBoost Test MSE: 11.2592
# Route ID: 8AX
# Train set size: (4252, 18)
# Test set size: (519, 18)
# Validation MSE: 28.6311
# XGBoost Test MSE: 27.5152
# Route ID: 8BX
# Train set size: (4377, 18)
# Test set size: (517, 18)
# Validation MSE: 37.6848
# XGBoost Test MSE: 115.5365
# Skipping route 9 due to empty train/test set.
# Route ID: 9
# Train set size: (16137, 18)
# Test set size: (3669, 18)
# Validation MSE: 9.3954
# XGBoost Test MSE: 11.7004
# Route ID: 90
# Train set size: (8321, 18)
# Test set size: (1025, 18)
# Validation MSE: 16.8322
# XGBoost Test MSE: 14.8001
# Skipping route 91 due to empty train/test set.
# Route ID: 91
# Train set size: (7018, 18)
# Test set size: (1345, 18)
# Validation MSE: 10.9888
# XGBoost Test MSE: 17.2622
# Route ID: 9R
# Train set size: (13277, 18)
# Test set size: (1571, 18)
# Validation MSE: 10.4528
# XGBoost Test MSE: 11.6955
# Route ID: CA
# Train set size: (12589, 18)
# Test set size: (2043, 18)
# Validation MSE: 165.0410
# XGBoost Test MSE: 373.0080
# Route ID: F
# Train set size: (24721, 18)
# Test set size: (3008, 18)
# Validation MSE: 21.1728
# XGBoost Test MSE: 25.1105
# Skipping route FBUS due to empty train/test set.
# Route ID: J
# Train set size: (30156, 18)
# Test set size: (3725, 18)
# Validation MSE: 22.1221
# XGBoost Test MSE: 16.0994
# Route ID: K
# Train set size: (27085, 18)
# Test set size: (3288, 18)
# Validation MSE: 11.5208
# XGBoost Test MSE: 17.8422
# Route ID: KBUS
# Train set size: (4581, 18)
# Test set size: (543, 18)
# Validation MSE: 58.8133
# XGBoost Test MSE: 11.3112
# Skipping route KLM due to empty train/test set.
# Skipping route L due to empty train/test set.
# Skipping route LBUS due to empty train/test set.
# Route ID: LOWL
# Train set size: (13252, 18)
# Test set size: (1302, 18)
# Validation MSE: 8.4743
# XGBoost Test MSE: 15.1570
# Route ID: M
# Train set size: (28579, 18)
# Test set size: (3632, 18)
# Validation MSE: 25.9760
# XGBoost Test MSE: 27.7583
# Skipping route MBUS due to empty train/test set.
# Route ID: N
# Train set size: (29243, 18)
# Test set size: (3559, 18)
# Validation MSE: 23.6941
# XGBoost Test MSE: 5.2367
# Route ID: NBUS
# Train set size: (4094, 18)
# Test set size: (476, 18)
# Validation MSE: 26.6493
# XGBoost Test MSE: 16.4173
# Route ID: NOWL
# Train set size: (9569, 18)
# Test set size: (1161, 18)
# Validation MSE: 15.7190
# XGBoost Test MSE: 14.3896
# Route ID: PH
# Train set size: (16974, 18)
# Test set size: (2639, 18)
# Validation MSE: 184.6885
# XGBoost Test MSE: 232.8006
# Route ID: PM
# Train set size: (15429, 18)
# Test set size: (2423, 18)
# Validation MSE: 206.7552
# XGBoost Test MSE: 300.6040
# Skipping route S due to empty train/test set.
# Route ID: T
# Train set size: (29400, 18)
# Test set size: (3525, 18)
# Validation MSE: 15.4172
# XGBoost Test MSE: 18.1215
# Route ID: TBUS
# Train set size: (3862, 18)
# Test set size: (472, 18)
# Validation MSE: 21.7592
# XGBoost Test MSE: 93.3044
# Overall Test MSE: 24.7497
